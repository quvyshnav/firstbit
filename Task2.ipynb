# %% [markdown]
# <a href="https://colab.research.google.com/github/quvyshnav/firstbit/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the file
df = pd.read_excel('Task2.xlsx')
df.head(1)
# Out:
#                  VIN  TRANSACTION_ID               CORRECTION_VERBATIM  \
# 0  3HCFDDE89SH220903           13021  REPLACED STEERING WHEEL NOW OKAY
#
#              CUSTOMER_VERBATIM REPAIR_DATE             CAUSAL_PART_NM  \
# 0  STEERING WHEEL COMING APART  2024-01-02  WHEEL ASM-STRG *JET BLACK
#
#   GLOBAL_LABOR_CODE_DESCRIPTION          PLATFORM BODY_STYLE   VPPC  ...  \
# 0    Steering Wheel Replacement  Full-Size Trucks   Crew Cab  T1CCF  ...
#
#   TRANSMISSION_TRACE_NBR  SRC_TXN_ID SRC_VER_NBR TRANSACTION_CNTR MEDIA_FLAG  \
# 0       S2210121CNJX0941  2808908219           6                1          N
#
#   VIN_MODL_DESGTR LINE_SERIES LAST_KNOWN_DELVRY_TYPE_CD  NON_CAUSAL_PART_QTY  \
# 0         CF10543        1500                      21.0                    0
#
#   SALES_REGION_CODE
# 0                 1
#
# [1 rows x 52 columns]

# %% [markdown]
# #### Descriptive Analysis

# %%
#Checking the dimension of dataframe.
df.shape
# Out:
# (100, 52)

# %%
#Summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 52 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   VIN                            100 non-null    object
#  1   TRANSACTION_ID                 100 non-null    int64
#  2   CORRECTION_VERBATIM            100 non-null    object
#  3   CUSTOMER_VERBATIM              100 non-null    object
#  4   REPAIR_DATE                    100 non-null    datetime64[ns]
#  5   CAUSAL_PART_NM                 95 non-null     object
#  6   GLOBAL_LABOR_CODE_DESCRIPTION  100 non-null    object
#  7   PLATFORM                       100 non-null    object
#  8   BODY_STYLE                     100 non-null    object
#  9   VPPC                           100 non-null    object
#  10  PLANT                          99 non-null     object
#  11  BUILD_COUNTRY                  100 non-null    object
# ...

# %%
#descriptive stats for numerical data.
df.describe().transpose()
# Out:
#                            count                 mean                  min  \
# TRANSACTION_ID             100.0              13036.9              13021.0
# REPAIR_DATE                  100  2024-01-22 07:26:24  2024-01-02 00:00:00
# DEALER_REGION              100.0                 1.09                  1.0
# REPAIR_AGE                 100.0                14.94                  0.0
# KM                         100.0             24914.23                  3.0
# COMPLAINT_CD_CSI           100.0                  0.0                  0.0
# ORD_SELLING_SRC_CD         100.0                24.59                 11.0
# GLOBAL_LABOR_CODE          100.0                251.9                 20.0
# CAMPAIGN_NBR                 0.0                  NaN                  NaN
# REPORTING_COST             100.0             531.1932                27.69
# TOTALCOST                   94.0           561.162128                27.69
# ...

# %%
#Descriptive stats of categorical columns.
df.describe(include='object').transpose()
# Out:
#                               count unique  \
# VIN                             100     98
# CORRECTION_VERBATIM             100     93
# CUSTOMER_VERBATIM               100    100
# CAUSAL_PART_NM                   95     18
# GLOBAL_LABOR_CODE_DESCRIPTION   100      4
# PLATFORM                        100     11
# BODY_STYLE                      100      6
# VPPC                            100     26
# PLANT                            99     11
# BUILD_COUNTRY                   100      3
# LAST_KNOWN_DLR_NAME             100    100
# LAST_KNOWN_DLR_CITY             100     94
# REPAIRING_DEALER_CODE           100     95
# DEALER_NAME                     100    100
# REPAIR_DLR_CITY                 100     93
# STATE                            98     39
# REPAIR_DLR_POSTAL_CD             98     92
# COMPLAINT_CD                    100      7
# VEH_TEST_GRP                     98     23
# COUNTRY_SALE_ISO                100      6
# OPTN_FAMLY_CERTIFICATION         90      3
# ...

# %%
#checking missing value count.
df.isnull().sum()
# Out:
# VIN                                0
# TRANSACTION_ID                     0
# CORRECTION_VERBATIM                0
# CUSTOMER_VERBATIM                  0
# REPAIR_DATE                        0
# CAUSAL_PART_NM                     5
# GLOBAL_LABOR_CODE_DESCRIPTION      0
# PLATFORM                           0
# BODY_STYLE                         0
# VPPC                               0
# PLANT                              1
# BUILD_COUNTRY                      0
# LAST_KNOWN_DLR_NAME                0
# LAST_KNOWN_DLR_CITY                0
# REPAIRING_DEALER_CODE              0
# DEALER_NAME                        0
# REPAIR_DLR_CITY                    0
# STATE                              2
# DEALER_REGION                      0
# REPAIR_DLR_POSTAL_CD               2
# REPAIR_AGE                         0
# KM                                 0
# COMPLAINT_CD_CSI                   0
# COMPLAINT_CD                       0
# VEH_TEST_GRP                       2
# ...

# %%
columns = df.columns
columns
# Out:
# Index(['VIN', 'TRANSACTION_ID', 'CORRECTION_VERBATIM', 'CUSTOMER_VERBATIM',
#        'REPAIR_DATE', 'CAUSAL_PART_NM', 'GLOBAL_LABOR_CODE_DESCRIPTION',
#        'PLATFORM', 'BODY_STYLE', 'VPPC', 'PLANT', 'BUILD_COUNTRY',
#        'LAST_KNOWN_DLR_NAME', 'LAST_KNOWN_DLR_CITY', 'REPAIRING_DEALER_CODE',
#        'DEALER_NAME', 'REPAIR_DLR_CITY', 'STATE', 'DEALER_REGION',
#        'REPAIR_DLR_POSTAL_CD', 'REPAIR_AGE', 'KM', 'COMPLAINT_CD_CSI',
#        'COMPLAINT_CD', 'VEH_TEST_GRP', 'COUNTRY_SALE_ISO',
#        'ORD_SELLING_SRC_CD', 'OPTN_FAMLY_CERTIFICATION',
#        'OPTF_FAMLY_EMISSIOF_SYSTEM', 'GLOBAL_LABOR_CODE',
#        'TRANSACTION_CATEGORY', 'CAMPAIGN_NBR', 'REPORTING_COST', 'TOTALCOST',
#        'LBRCOST', 'ENGINE', 'ENGINE_DESC', 'TRANSMISSION', 'TRANSMISSION_DESC',
#        'ENGINE_SOURCE_PLANT', 'ENGINE_TRACE_NBR', 'TRANSMISSION_SOURCE_PLANT',
#        'TRANSMISSION_TRACE_NBR', 'SRC_TXN_ID', 'SRC_VER_NBR',
# ...

# %%
type_data = df.dtypes
type_data
# Out:
# VIN                                      object
# TRANSACTION_ID                            int64
# CORRECTION_VERBATIM                      object
# CUSTOMER_VERBATIM                        object
# REPAIR_DATE                      datetime64[ns]
# CAUSAL_PART_NM                           object
# GLOBAL_LABOR_CODE_DESCRIPTION            object
# PLATFORM                                 object
# BODY_STYLE                               object
# VPPC                                     object
# PLANT                                    object
# BUILD_COUNTRY                            object
# LAST_KNOWN_DLR_NAME                      object
# LAST_KNOWN_DLR_CITY                      object
# REPAIRING_DEALER_CODE                    object
# DEALER_NAME                              object
# REPAIR_DLR_CITY                          object
# STATE                                    object
# DEALER_REGION                             int64
# REPAIR_DLR_POSTAL_CD                     object
# ...

# %%
columns = columns.to_list()
columns
# Out:
# ['VIN',
#  'TRANSACTION_ID',
#  'CORRECTION_VERBATIM',
#  'CUSTOMER_VERBATIM',
#  'REPAIR_DATE',
#  'CAUSAL_PART_NM',
#  'GLOBAL_LABOR_CODE_DESCRIPTION',
#  'PLATFORM',
#  'BODY_STYLE',
#  'VPPC',
#  'PLANT',
#  'BUILD_COUNTRY',
#  'LAST_KNOWN_DLR_NAME',
#  'LAST_KNOWN_DLR_CITY',
#  'REPAIRING_DEALER_CODE',
#  'DEALER_NAME',
#  'REPAIR_DLR_CITY',
#  'STATE',
#  'DEALER_REGION',
#  'REPAIR_DLR_POSTAL_CD',
#  'REPAIR_AGE',
#  'KM',
#  'COMPLAINT_CD_CSI',
#  'COMPLAINT_CD',
#  'VEH_TEST_GRP',
#  'COUNTRY_SALE_ISO',
#  'ORD_SELLING_SRC_CD',
#  'OPTN_FAMLY_CERTIFICATION',
#  'OPTF_FAMLY_EMISSIOF_SYSTEM',
#  'GLOBAL_LABOR_CODE',
#  'TRANSACTION_CATEGORY',
#  'CAMPAIGN_NBR',
#  'REPORTING_COST',
#  'TOTALCOST',
#  'LBRCOST',
#  'ENGINE',
#  'ENGINE_DESC',
#  'TRANSMISSION',
#  'TRANSMISSION_DESC',
#  'ENGINE_SOURCE_PLANT',
#  'ENGINE_TRACE_NBR',
#  'TRANSMISSION_SOURCE_PLANT',
#  'TRANSMISSION_TRACE_NBR',
#  'SRC_TXN_ID',
#  'SRC_VER_NBR',
#  'TRANSACTION_CNTR',
#  'MEDIA_FLAG',
# ...

# %%
cat_col = df.select_dtypes(include=['object']).columns.tolist()
cat_col
# Out:
# ['VIN',
#  'CORRECTION_VERBATIM',
#  'CUSTOMER_VERBATIM',
#  'CAUSAL_PART_NM',
#  'GLOBAL_LABOR_CODE_DESCRIPTION',
#  'PLATFORM',
#  'BODY_STYLE',
#  'VPPC',
#  'PLANT',
#  'BUILD_COUNTRY',
#  'LAST_KNOWN_DLR_NAME',
#  'LAST_KNOWN_DLR_CITY',
#  'REPAIRING_DEALER_CODE',
#  'DEALER_NAME',
#  'REPAIR_DLR_CITY',
#  'STATE',
#  'REPAIR_DLR_POSTAL_CD',
#  'COMPLAINT_CD',
#  'VEH_TEST_GRP',
#  'COUNTRY_SALE_ISO',
#  'OPTN_FAMLY_CERTIFICATION',
#  'OPTF_FAMLY_EMISSIOF_SYSTEM',
#  'TRANSACTION_CATEGORY',
#  'ENGINE',
#  'ENGINE_DESC',
#  'TRANSMISSION',
#  'TRANSMISSION_DESC',
#  'ENGINE_SOURCE_PLANT',
#  'ENGINE_TRACE_NBR',
#  'TRANSMISSION_TRACE_NBR',
#  'MEDIA_FLAG',
#  'VIN_MODL_DESGTR',
#  'LINE_SERIES']

# %%
num_col = df.select_dtypes(include=['int64','float64']).columns.tolist()
num_col
# Out:
# ['TRANSACTION_ID',
#  'DEALER_REGION',
#  'REPAIR_AGE',
#  'KM',
#  'COMPLAINT_CD_CSI',
#  'ORD_SELLING_SRC_CD',
#  'GLOBAL_LABOR_CODE',
#  'CAMPAIGN_NBR',
#  'REPORTING_COST',
#  'TOTALCOST',
#  'LBRCOST',
#  'TRANSMISSION_SOURCE_PLANT',
#  'SRC_TXN_ID',
#  'SRC_VER_NBR',
#  'TRANSACTION_CNTR',
#  'LAST_KNOWN_DELVRY_TYPE_CD',
#  'NON_CAUSAL_PART_QTY',
#  'SALES_REGION_CODE']

# %%
df.head()
# Out:
#                  VIN  TRANSACTION_ID  \
# 0  3HCFDDE89SH220903           13021
# 1  1HRFFEE8XSZ230636           13028
# 2  1HYKSMRK6SZ000990           13035
# 3  3HCFDFEL3SH241701           13021
# 4  1HRFFHEL1RZ181474           13021
#
#                                  CORRECTION_VERBATIM  \
# 0                   REPLACED STEERING WHEEL NOW OKAY
# 1  CHECKED - FOUND DTC'S U0229 - U1530 SET IN BCM...
# 2  APPROVED 4.9(OLH) FOR ADDED DIAGNOSTICS WITH T...
# 3                         STEERING WHEEL REPLACEMENT
# 4      REPLACED STEERING MESSAGE NO LONGER DISPLAYED
#
#                                    CUSTOMER_VERBATIM REPAIR_DATE  \
# 0                        STEERING WHEEL COMING APART  2024-01-02
# 1         CUSTOMER STATES HEATED STEERING WHEEL INOP  2024-01-03
# 2  OWNER REPORTS: THE SUPER CRUISE BAR ON THE STE...  2024-01-04
# 3  CUSTOMER STATES THE LETTERING AND FINISH ON TH...  2024-01-04
# 4  C/S: CUSTOMER STATES THE SERVICE DRIVER ASSIST...  2024-01-05
#
# ...

# %% [markdown]
# #### Columnwise Analysis - Chekcing missing values and data types

# %%
def analyse_column(names):
  col_analysis = []
  for col in names:
    col_data = df[col]
    col_type = col_data.dtype
    unique_values = col_data.nunique()
    miss_values = col_data.isnull().sum()

    col_analysis.append({
        "Column Name": col,
        "Data Type": str(col_type),
        "Unique Values": unique_values,
        "Missing Values": miss_values
    })
  column_analysis = pd.DataFrame(col_analysis)
  return column_analysis

# %%
#Checking the unique values and missing values - for categorical columns
cat_col_analysis = analyse_column(cat_col)
cat_col_analysis
# Out:
#                       Column Name Data Type  Unique Values  Missing Values
# 0                             VIN    object             98               0
# 1             CORRECTION_VERBATIM    object             93               0
# 2               CUSTOMER_VERBATIM    object            100               0
# 3                  CAUSAL_PART_NM    object             18               5
# 4   GLOBAL_LABOR_CODE_DESCRIPTION    object              4               0
# 5                        PLATFORM    object             11               0
# 6                      BODY_STYLE    object              6               0
# 7                            VPPC    object             26               0
# 8                           PLANT    object             11               1
# 9                   BUILD_COUNTRY    object              3               0
# 10            LAST_KNOWN_DLR_NAME    object            100               0
# ...

# %%
#Checking the unique values and missing values - for numerical columns
num_col_analysis = analyse_column(num_col)
num_col_analysis
# Out:
#                   Column Name Data Type  Unique Values  Missing Values
# 0              TRANSACTION_ID     int64             32               0
# 1               DEALER_REGION     int64              2               0
# 2                  REPAIR_AGE     int64             35               0
# 3                          KM     int64            100               0
# 4            COMPLAINT_CD_CSI     int64              1               0
# 5          ORD_SELLING_SRC_CD     int64              7               0
# 6           GLOBAL_LABOR_CODE     int64              4               0
# 7                CAMPAIGN_NBR   float64              0             100
# 8              REPORTING_COST   float64            100               0
# 9                   TOTALCOST   float64             94               6
# 10                    LBRCOST   float64             99               0
# 11  TRANSMISSION_SOURCE_PLANT   float64              6              12
# ...

# %%
#Handling missing values
df.drop('CAMPAIGN_NBR',inplace = True,axis = 1)

# %%
for i in range(0,100):
  if df['TOTALCOST'][i]=='':
    df['TOTALCOST'] = df['REPORTING_COST']
  else:
    df['TOTALCOST'] = df['TOTALCOST']

# %%
missing = df.isnull().sum()
missing_col = missing[missing>0].index.to_list()
missing_col
# Out:
# ['CAUSAL_PART_NM',
#  'PLANT',
#  'STATE',
#  'REPAIR_DLR_POSTAL_CD',
#  'VEH_TEST_GRP',
#  'OPTN_FAMLY_CERTIFICATION',
#  'OPTF_FAMLY_EMISSIOF_SYSTEM',
#  'TOTALCOST',
#  'ENGINE_SOURCE_PLANT',
#  'ENGINE_TRACE_NBR',
#  'TRANSMISSION_SOURCE_PLANT',
#  'TRANSMISSION_TRACE_NBR',
#  'LINE_SERIES',
#  'LAST_KNOWN_DELVRY_TYPE_CD']

# %%
for col in missing_col:
  df.fillna({col : df[col].mode()[0]},inplace = True)
# Out:
# <ipython-input-205-f6587dbd6f03>:2: UserWarning: Unable to sort modes: '<' not supported between instances of 'int' and 'str'
#   df.fillna({col : df[col].mode()[0]},inplace = True)

# %%
df.isnull().sum()
# Out:
# VIN                              0
# TRANSACTION_ID                   0
# CORRECTION_VERBATIM              0
# CUSTOMER_VERBATIM                0
# REPAIR_DATE                      0
# CAUSAL_PART_NM                   0
# GLOBAL_LABOR_CODE_DESCRIPTION    0
# PLATFORM                         0
# BODY_STYLE                       0
# VPPC                             0
# PLANT                            0
# BUILD_COUNTRY                    0
# LAST_KNOWN_DLR_NAME              0
# LAST_KNOWN_DLR_CITY              0
# REPAIRING_DEALER_CODE            0
# DEALER_NAME                      0
# REPAIR_DLR_CITY                  0
# STATE                            0
# DEALER_REGION                    0
# REPAIR_DLR_POSTAL_CD             0
# REPAIR_AGE                       0
# KM                               0
# COMPLAINT_CD_CSI                 0
# COMPLAINT_CD                     0
# VEH_TEST_GRP                     0
# COUNTRY_SALE_ISO                 0
# ORD_SELLING_SRC_CD               0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   VIN                            100 non-null    object
#  1   TRANSACTION_ID                 100 non-null    int64
#  2   CORRECTION_VERBATIM            100 non-null    object
#  3   CUSTOMER_VERBATIM              100 non-null    object
#  4   REPAIR_DATE                    100 non-null    datetime64[ns]
#  5   CAUSAL_PART_NM                 100 non-null    object
#  6   GLOBAL_LABOR_CODE_DESCRIPTION  100 non-null    object
#  7   PLATFORM                       100 non-null    object
#  8   BODY_STYLE                     100 non-null    object
#  9   VPPC                           100 non-null    object
#  10  PLANT                          100 non-null    object
#  11  BUILD_COUNTRY                  100 non-null    object
# ...

# %%
columns = df.columns.to_list()
num_field = ('REPAIR_AGE','REPORTING_COST','TOTALCOST','LBRCOST','KM','REPAIR_DATE')
obj_field = [field for field in columns if field not in num_field]
len(obj_field)
# Out:
# 45

# %%
#for col in obj_field:
#  df[col] = df[col].astype('object')
#  df[col].lower()
#Removing inconsistancies

for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].str.strip().str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   VIN                            100 non-null    object
#  1   TRANSACTION_ID                 100 non-null    int64
#  2   CORRECTION_VERBATIM            100 non-null    object
#  3   CUSTOMER_VERBATIM              100 non-null    object
#  4   REPAIR_DATE                    100 non-null    datetime64[ns]
#  5   CAUSAL_PART_NM                 100 non-null    object
#  6   GLOBAL_LABOR_CODE_DESCRIPTION  100 non-null    object
#  7   PLATFORM                       100 non-null    object
#  8   BODY_STYLE                     100 non-null    object
#  9   VPPC                           100 non-null    object
#  10  PLANT                          100 non-null    object
#  11  BUILD_COUNTRY                  100 non-null    object
# ...

# %%
df.head()
# Out:
#                  VIN  TRANSACTION_ID  \
# 0  3hcfdde89sh220903           13021
# 1  1hrffee8xsz230636           13028
# 2  1hyksmrk6sz000990           13035
# 3  3hcfdfel3sh241701           13021
# 4  1hrffhel1rz181474           13021
#
#                                  CORRECTION_VERBATIM  \
# 0                   replaced steering wheel now okay
# 1  checked - found dtc's u0229 - u1530 set in bcm...
# 2  approved 4.9(olh) for added diagnostics with t...
# 3                         steering wheel replacement
# 4      replaced steering message no longer displayed
#
#                                    CUSTOMER_VERBATIM REPAIR_DATE  \
# 0                        steering wheel coming apart  2024-01-02
# 1         customer states heated steering wheel inop  2024-01-03
# 2  owner reports: the super cruise bar on the ste...  2024-01-04
# 3  customer states the lettering and finish on th...  2024-01-04
# 4  c/s: customer states the service driver assist...  2024-01-05
#
# ...

# %% [markdown]
# ### Vizualizing Distributions

# %%
num_col = ['TRANSACTION_ID',
 'DEALER_REGION',
 'REPAIR_AGE',
 'KM',
 'COMPLAINT_CD_CSI',
 'ORD_SELLING_SRC_CD',
 'GLOBAL_LABOR_CODE',
 'REPORTING_COST',
 'TOTALCOST',
 'LBRCOST',
 'TRANSMISSION_SOURCE_PLANT',
 'SRC_TXN_ID',
 'SRC_VER_NBR',
 'TRANSACTION_CNTR',
 'LAST_KNOWN_DELVRY_TYPE_CD',
 'NON_CAUSAL_PART_QTY',
 'SALES_REGION_CODE']
#--- 1. Correlation Heat Map ---
plt.figure(figsize=(12, 8))
sns.heatmap(df[num_col].corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
# --- 2. Distribution of TOTALCOST ---
plt.figure(figsize=(8, 5))
sns.histplot(df["TOTALCOST"].dropna(), bins=20, kde=True, color="blue")
plt.title("Distribution of TOTALCOST")
plt.xlabel("TOTALCOST")
plt.ylabel("Frequency")
plt.show()

# %%
sns.set(style="whitegrid")
# --- 3. Sales by Region ---
plt.figure(figsize=(8, 5))
sns.countplot(x=df['SALES_REGION_CODE'], palette='viridis')
plt.title('Sales by Region')
plt.xlabel('Region Code')
plt.ylabel('Number of Sales')
plt.show()
# Out:
# <ipython-input-214-4726754de6b9>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['SALES_REGION_CODE'], palette='viridis')

# %%
# --- 4 . Boxplot of TOTALCOST by PLATFORM ---
plt.figure(figsize=(10, 5))
sns.boxplot(x="PLATFORM", y="TOTALCOST", data=df, palette="Set2")
plt.xticks(rotation=45)
plt.title("TOTALCOST by PLATFORM")
plt.show()
# Out:
# <ipython-input-215-9bf16fb01705>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="PLATFORM", y="TOTALCOST", data=df, palette="Set2")

# %%
# --- 5. Most Common Repairs ---
sns.countplot(y=df['GLOBAL_LABOR_CODE_DESCRIPTION'], order=df['GLOBAL_LABOR_CODE_DESCRIPTION'].value_counts().index)
plt.title('Most Common Repairs')
plt.xlabel('Count')
plt.ylabel('Repair Description')
plt.show()

# %%
# --- 6. Top 5 Selling Vehicle Models ---
top_models = df['VIN_MODL_DESGTR'].value_counts().head(5)
plt.figure(figsize=(8, 5))
sns.barplot(x=top_models.index, y=top_models.values, palette='viridis')
plt.title('Top 5 Selling Vehicle Models')
plt.xlabel('Vehicle Model')
plt.ylabel('Number of Sales')
plt.show()
# Out:
# <ipython-input-217-ff96b33f2bbb>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_models.index, y=top_models.values, palette='viridis')

# %%
# --- 7. Mileage vs. Repair Age ---
sns.scatterplot(x=df['KM'], y=df['REPAIR_AGE'])
plt.title('Mileage vs. Repair Age')
plt.xlabel('Mileage')
plt.ylabel('Repair Age')
plt.show()

# %%
# --- 8. Cost Over Time ---
plt.figure(figsize=(10, 5))
sns.lineplot(x=df['REPAIR_DATE'], y=df['TOTALCOST'], marker='o', color='b')
plt.title('Cost Over Timee')
plt.xlabel('Date')
plt.ylabel('Total Cost')
plt.xticks(rotation=45)
plt.show()

# %%
# --- 9. Sales by Vehicle Category ---
category_sales = df['PLATFORM'].value_counts()
plt.figure(figsize=(10, 5))
sns.barplot(x=category_sales.index, y=category_sales.values, palette='coolwarm')
plt.title('Sales by Vehicle Category')
plt.xlabel('Vehicle Category')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-220-c71e1adb49ef>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_sales.index, y=category_sales.values, palette='coolwarm')

# %%
# --- 10. Sales by Delivery Type ---
delivery_sales = df['LAST_KNOWN_DELVRY_TYPE_CD'].value_counts()
plt.figure(figsize=(8, 5))
sns.barplot(x=delivery_sales.index, y=delivery_sales.values, palette='magma')
plt.title('Sales by Delivery Type')
plt.xlabel('Delivery Type Code')
plt.ylabel('Number of Sales')
plt.show()
# Out:
# <ipython-input-221-fff219dd7bdc>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=delivery_sales.index, y=delivery_sales.values, palette='magma')
